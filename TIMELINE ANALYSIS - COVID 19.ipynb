# %% [markdown]
# <b style="color:Green;font-size:32px;">Sparks Foundation - Data Science & Analytics Internship!</b><br>
# <b style="color:#ff3333;font-size:19px;">TASK 8 : Timeline Analysis : Covid-19
# (Level - Advanced)</b><br>
# <b style="font-size:17px;">Description of the Task 8 :</b><br>
# <ul style="font-size:15px;line-height:18px;"><b><li>Create a storyboard showing spread of Covid-19 cases in your country or any
# region (Asia, Europe, BRICS etc) </li>
# <li>Use animation, timeline and annotations to create attractive and interactive
# dashboards and story
#  </li>
#     <li>Identify interesting patterns and possible reasons helping Covid-19 spread with
# basic as well as advanced charts
#  </li>
#     <li>Dataset: Daily updated .csv file on https://bit.ly/30d2gdi</a></li></b>
# <li><b> Github Link <a>https://github.com/ManjotSinghSindhu/THE-SPARK-FOUNDATION</a></li></b>
# </ul>

# %% [markdown]
# ### Importing Needed Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# ### Importing the Data

# %%
df = pd.read_csv("owid-covid-data.csv")

# %%
#Take a look at dataset

df.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-23          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-24          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-25          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-26          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-27          NaN        0.0
# 5      AFG      Asia  Afghanistan  2020-01-28          NaN        0.0
# 6      AFG      Asia  Afghanistan  2020-01-29          NaN        0.0
# 7      AFG      Asia  Afghanistan  2020-01-30          NaN        0.0
# 8      AFG      Asia  Afghanistan  2020-01-31          NaN        0.0
# 9      AFG      Asia  Afghanistan  2020-02-01          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         0.0                  NaN
# 1                 NaN           NaN         0.0                  NaN
# 2                 NaN           NaN         0.0                  NaN
# 3                 NaN           NaN         0.0                  NaN
# 4                 NaN           NaN         0.0                  NaN
# 5                 0.0           NaN         0.0                  0.0
# 6                 0.0           NaN         0.0                  0.0
# 7                 0.0           NaN         0.0                  0.0
# 8                 0.0           NaN         0.0                  0.0
# 9                 0.0           NaN         0.0                  0.0
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# 1           ...                   1803.987              NaN
# 2           ...                   1803.987              NaN
# 3           ...                   1803.987              NaN
# 4           ...                   1803.987              NaN
# 5           ...                   1803.987              NaN
# 6           ...                   1803.987              NaN
# 7           ...                   1803.987              NaN
# 8           ...                   1803.987              NaN
# 9           ...                   1803.987              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                597.029                 9.59             NaN           NaN
# 1                597.029                 9.59             NaN           NaN
# 2                597.029                 9.59             NaN           NaN
# 3                597.029                 9.59             NaN           NaN
# 4                597.029                 9.59             NaN           NaN
# 5                597.029                 9.59             NaN           NaN
# 6                597.029                 9.59             NaN           NaN
# 7                597.029                 9.59             NaN           NaN
# 8                597.029                 9.59             NaN           NaN
# 9                597.029                 9.59             NaN           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
# 5                  37.746                         0.5            64.83
# 6                  37.746                         0.5            64.83
# 7                  37.746                         0.5            64.83
# 8                  37.746                         0.5            64.83
# 9                  37.746                         0.5            64.83
#
#    human_development_index
# 0                    0.498
# 1                    0.498
# 2                    0.498
# 3                    0.498
# 4                    0.498
# 5                    0.498
# 6                    0.498
# 7                    0.498
# 8                    0.498
# 9                    0.498
#
# [10 rows x 50 columns]

# %%
#Take a look at dataset

df.tail(10)
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 60470      ZWE    Africa  Zimbabwe  2020-11-24       9398.0       90.0
# 60471      ZWE    Africa  Zimbabwe  2020-11-25       9508.0      110.0
# 60472      ZWE    Africa  Zimbabwe  2020-11-26       9623.0      115.0
# 60473      ZWE    Africa  Zimbabwe  2020-11-27       9714.0       91.0
# 60474      ZWE    Africa  Zimbabwe  2020-11-28       9822.0      108.0
# 60475      ZWE    Africa  Zimbabwe  2020-11-29       9822.0        0.0
# 60476      ZWE    Africa  Zimbabwe  2020-11-30       9950.0      128.0
# 60477      ZWE    Africa  Zimbabwe  2020-12-01      10129.0      179.0
# 60478      ZWE    Africa  Zimbabwe  2020-12-02      10129.0        0.0
# 60479      ZWE    Africa  Zimbabwe  2020-12-03      10424.0      295.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 60470              64.714         274.0         1.0                2.000
# 60471              75.286         274.0         0.0                1.857
# 60472              82.429         274.0         0.0                1.286
# 60473              84.857         275.0         1.0                1.429
# 60474              92.857         275.0         0.0                1.429
# 60475              86.000         275.0         0.0                1.000
# 60476              91.714         276.0         1.0                0.429
# 60477             104.429         277.0         1.0                0.429
# 60478              88.714         277.0         0.0                0.429
# 60479             114.429         280.0         3.0                0.857
#
#                 ...             gdp_per_capita  extreme_poverty  \
# 60470           ...                   1899.775             21.4
# 60471           ...                   1899.775             21.4
# 60472           ...                   1899.775             21.4
# 60473           ...                   1899.775             21.4
# 60474           ...                   1899.775             21.4
# 60475           ...                   1899.775             21.4
# 60476           ...                   1899.775             21.4
# 60477           ...                   1899.775             21.4
# 60478           ...                   1899.775             21.4
# 60479           ...                   1899.775             21.4
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 60470                307.846                 1.82             1.6
# 60471                307.846                 1.82             1.6
# 60472                307.846                 1.82             1.6
# 60473                307.846                 1.82             1.6
# 60474                307.846                 1.82             1.6
# 60475                307.846                 1.82             1.6
# 60476                307.846                 1.82             1.6
# 60477                307.846                 1.82             1.6
# 60478                307.846                 1.82             1.6
# 60479                307.846                 1.82             1.6
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 60470          30.7                  36.791                         1.7
# 60471          30.7                  36.791                         1.7
# 60472          30.7                  36.791                         1.7
# 60473          30.7                  36.791                         1.7
# 60474          30.7                  36.791                         1.7
# 60475          30.7                  36.791                         1.7
# 60476          30.7                  36.791                         1.7
# 60477          30.7                  36.791                         1.7
# 60478          30.7                  36.791                         1.7
# 60479          30.7                  36.791                         1.7
#
#        life_expectancy  human_development_index
# 60470            61.49                    0.535
# 60471            61.49                    0.535
# 60472            61.49                    0.535
# 60473            61.49                    0.535
# 60474            61.49                    0.535
# 60475            61.49                    0.535
# 60476            61.49                    0.535
# 60477            61.49                    0.535
# 60478            61.49                    0.535
# 60479            61.49                    0.535
#
# [10 rows x 50 columns]

# %% [markdown]
# ### Data Exploration

# %%
#Summarize the data

df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.174100e+04   60357.000000        59401.000000  4.388300e+04
# mean   2.137754e+05    2161.141276         2133.925522  8.050394e+03
# std    2.062972e+06   20602.745438        20096.488969  6.303614e+04
# min    1.000000e+00  -10034.000000         -525.000000  1.000000e+00
# 25%    3.440000e+02       0.000000            0.429000  2.100000e+01
# 50%    3.556000e+03      13.000000           18.857000  1.200000e+02
# 75%    3.512900e+04     249.000000          269.143000  9.900000e+02
# max    6.522056e+07  690127.000000       600775.429000  1.506251e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  60357.000000         59401.000000             51440.000000
# mean      49.910831            49.567075              3534.850155
# std      419.073971           404.168579              7193.403116
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000                70.337750
# 50%        0.000000             0.286000               563.674000
# 75%        4.000000             4.429000              3614.574000
# max    12825.000000         10538.571000             89354.818000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           60041.000000                    59090.000000
# mean               39.281055                       38.580438
# std               134.248362                      106.420958
# min             -2153.437000                     -276.825000
# 25%                 0.000000                        0.070000
# 50%                 1.661000                        2.763000
# 75%                23.290000                       25.926750
# max              8652.658000                     2648.773000
#
#        total_deaths_per_million           ...             gdp_per_capita  \
# count              43595.000000           ...               57313.000000
# mean                 101.094200           ...               18424.124159
# std                  196.022826           ...               19420.396223
# min                    0.001000           ...                 661.240000
# 25%                    3.663000           ...                3823.194000
# 50%                   19.070000           ...               11840.846000
# 75%                   89.229000           ...               26382.287000
# max                 1469.678000           ...              116935.600000
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# count     39230.000000           57882.000000         58577.000000
# mean         13.901575             261.965295             7.892263
# std          20.222847             120.643799             4.205662
# min           0.100000              79.370000             0.990000
# 25%           0.600000             170.050000             5.290000
# 50%           2.350000             243.964000             7.110000
# 75%          21.400000             331.430000            10.080000
# max          77.600000             724.417000            30.530000
#
#        female_smokers  male_smokers  handwashing_facilities  \
# count    44919.000000  44287.000000            30062.000000
# mean        10.353874     32.647201               50.324192
# std         10.390631     13.559705               31.732293
# min          0.100000      7.700000                1.188000
# 25%          1.900000     21.400000               19.351000
# 50%          6.200000     31.400000               49.542000
# 75%         19.100000     41.100000               82.502000
# max         44.000000     78.100000               98.999000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index
# count                52819.000000     59848.000000             57628.000000
# mean                     2.998858        72.843154                 0.708822
# std                      2.438902         7.544485                 0.154033
# min                      0.100000        53.280000                 0.354000
# 25%                      1.300000        67.270000                 0.588000
# 50%                      2.397000        74.250000                 0.741000
# 75%                      3.861000        77.970000                 0.825000
# max                     13.800000        86.750000                 0.953000
#
# [8 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60480 entries, 0 to 60479
# Data columns (total 50 columns):
# iso_code                              60164 non-null object
# continent                             59847 non-null object
# location                              60480 non-null object
# date                                  60480 non-null object
# total_cases                           51741 non-null float64
# new_cases                             60357 non-null float64
# new_cases_smoothed                    59401 non-null float64
# total_deaths                          43883 non-null float64
# new_deaths                            60357 non-null float64
# new_deaths_smoothed                   59401 non-null float64
# total_cases_per_million               51440 non-null float64
# new_cases_per_million                 60041 non-null float64
# new_cases_smoothed_per_million        59090 non-null float64
# total_deaths_per_million              43595 non-null float64
# new_deaths_per_million                60041 non-null float64
# new_deaths_smoothed_per_million       59090 non-null float64
# reproduction_rate                     39997 non-null float64
# icu_patients                          4694 non-null float64
# icu_patients_per_million              4694 non-null float64
# hosp_patients                         5679 non-null float64
# hosp_patients_per_million             5679 non-null float64
# weekly_icu_admissions                 457 non-null float64
# weekly_icu_admissions_per_million     457 non-null float64
# weekly_hosp_admissions                742 non-null float64
# weekly_hosp_admissions_per_million    742 non-null float64
# total_tests                           23983 non-null float64
# new_tests                             23837 non-null float64
# total_tests_per_thousand              23983 non-null float64
# new_tests_per_thousand                23837 non-null float64
# new_tests_smoothed                    26595 non-null float64
# new_tests_smoothed_per_thousand       26595 non-null float64
# positive_rate                         25129 non-null float64
# tests_per_case                        24538 non-null float64
# tests_units                           27586 non-null object
# stringency_index                      52701 non-null float64
# population                            60164 non-null float64
# population_density                    58577 non-null float64
# median_age                            57320 non-null float64
# aged_65_older                         56365 non-null float64
# aged_70_older                         57004 non-null float64
# gdp_per_capita                        57313 non-null float64
# extreme_poverty                       39230 non-null float64
# cardiovasc_death_rate                 57882 non-null float64
# diabetes_prevalence                   58577 non-null float64
# female_smokers                        44919 non-null float64
# male_smokers                          44287 non-null float64
# handwashing_facilities                30062 non-null float64
# hospital_beds_per_thousand            52819 non-null float64
# life_expectancy                       59848 non-null float64
# human_development_index               57628 non-null float64
# dtypes: float64(45), object(5)
# memory usage: 23.1+ MB

# %% [markdown]
# ### droping the Duplicates rows

# %%
df.shape
# Out:
# (60480, 50)

# %%
duplicate_rows_df = df[df.duplicated()]

print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 50)

# %%
df.count() #Used to count the number of rows
# Out:
# iso_code                              60164
# continent                             59847
# location                              60480
# date                                  60480
# total_cases                           51741
# new_cases                             60357
# new_cases_smoothed                    59401
# total_deaths                          43883
# new_deaths                            60357
# new_deaths_smoothed                   59401
# total_cases_per_million               51440
# new_cases_per_million                 60041
# new_cases_smoothed_per_million        59090
# total_deaths_per_million              43595
# new_deaths_per_million                60041
# new_deaths_smoothed_per_million       59090
# reproduction_rate                     39997
# icu_patients                           4694
# icu_patients_per_million               4694
# hosp_patients                          5679
# hosp_patients_per_million              5679
# weekly_icu_admissions                   457
# weekly_icu_admissions_per_million       457
# weekly_hosp_admissions                  742
# weekly_hosp_admissions_per_million      742
# total_tests                           23983
# new_tests                             23837
# total_tests_per_thousand              23983
# new_tests_per_thousand                23837
# new_tests_smoothed                    26595
# new_tests_smoothed_per_thousand       26595
# positive_rate                         25129
# tests_per_case                        24538
# tests_units                           27586
# stringency_index                      52701
# population                            60164
# population_density                    58577
# median_age                            57320
# aged_65_older                         56365
# aged_70_older                         57004
# gdp_per_capita                        57313
# extreme_poverty                       39230
# cardiovasc_death_rate                 57882
# diabetes_prevalence                   58577
# female_smokers                        44919
# male_smokers                          44287
# handwashing_facilities                30062
# hospital_beds_per_thousand            52819
# life_expectancy                       59848
# human_development_index               57628
# dtype: int64

# %%
#df = df.drop_duplicates()

#df.head()

# %%
#df.count()

# %% [markdown]
# ### Checking the Missing or Null values

# %%
print(df.isnull().sum())
# Out:
# iso_code                                316
# continent                               633
# location                                  0
# date                                      0
# total_cases                            8739
# new_cases                               123
# new_cases_smoothed                     1079
# total_deaths                          16597
# new_deaths                              123
# new_deaths_smoothed                    1079
# total_cases_per_million                9040
# new_cases_per_million                   439
# new_cases_smoothed_per_million         1390
# total_deaths_per_million              16885
# new_deaths_per_million                  439
# new_deaths_smoothed_per_million        1390
# reproduction_rate                     20483
# icu_patients                          55786
# icu_patients_per_million              55786
# hosp_patients                         54801
# hosp_patients_per_million             54801
# weekly_icu_admissions                 60023
# weekly_icu_admissions_per_million     60023
# weekly_hosp_admissions                59738
# weekly_hosp_admissions_per_million    59738
# total_tests                           36497
# new_tests                             36643
# total_tests_per_thousand              36497
# new_tests_per_thousand                36643
# new_tests_smoothed                    33885
# new_tests_smoothed_per_thousand       33885
# positive_rate                         35351
# tests_per_case                        35942
# tests_units                           32894
# stringency_index                       7779
# population                              316
# population_density                     1903
# median_age                             3160
# aged_65_older                          4115
# aged_70_older                          3476
# gdp_per_capita                         3167
# extreme_poverty                       21250
# cardiovasc_death_rate                  2598
# diabetes_prevalence                    1903
# female_smokers                        15561
# male_smokers                          16193
# handwashing_facilities                30418
# hospital_beds_per_thousand             7661
# life_expectancy                         632
# human_development_index                2852
# dtype: int64

# %%
#If you finds missing values in your data then remove it's by using following steps

#df = df.dropna() #Droping the missing values

#df.count()

# %%
#print(df.isnull().sum()) #After dropping the values

# %%
df1 = df[["date", "total_cases", "new_cases", "total_deaths", "new_tests", "total_tests"]]

df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2020-01-23          NaN        0.0           NaN        NaN          NaN
# 1  2020-01-24          NaN        0.0           NaN        NaN          NaN
# 2  2020-01-25          NaN        0.0           NaN        NaN          NaN
# 3  2020-01-26          NaN        0.0           NaN        NaN          NaN
# 4  2020-01-27          NaN        0.0           NaN        NaN          NaN

# %%
df1.date = pd.to_datetime(df.date)

df1.set_index('date', inplace = True)
# Out:
# C:\Users\Manjot singh\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df1.head()
# Out:
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2020-01-23          NaN        0.0           NaN        NaN          NaN
# 2020-01-24          NaN        0.0           NaN        NaN          NaN
# 2020-01-25          NaN        0.0           NaN        NaN          NaN
# 2020-01-26          NaN        0.0           NaN        NaN          NaN
# 2020-01-27          NaN        0.0           NaN        NaN          NaN

# %%
df1.tail()
# Out:
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2020-11-29       9822.0        0.0         275.0      965.0     168212.0
# 2020-11-30       9950.0      128.0         276.0      797.0     169009.0
# 2020-12-01      10129.0      179.0         277.0     1029.0     170038.0
# 2020-12-02      10129.0        0.0         277.0     1862.0     171900.0
# 2020-12-03      10424.0      295.0         280.0        NaN          NaN

# %%
df1.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5,0,'Month')

# %%
df1.total_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5,0,'Month')

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5,0,'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5,0,'Month')

# %%
df1.new_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5,0,'Month')

# %%
df1.total_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5,0,'Month')

# %% [markdown]
# ### Trends and Seasonality in TimeSeries Data

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_cases = df1[['new_cases']]
new_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_deaths = df1[['total_deaths']]
total_deaths.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_tests = df1[['new_tests']]
new_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_tests = df1[['total_tests']]
total_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
df_rm = pd.concat([total_cases.rolling(12).mean(), total_deaths.rolling(12).mean(), axis = 1])
df_rm.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);
# Out:
#   File "<ipython-input-33-c9cf221fe66b>", line 1
#     df_rm = pd.concat([total_cases.rolling(12).mean(), total_deaths.rolling(12).mean(), axis = 1])
#                                                                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Seasonal Patterns in Time Series Data

# %%
total_cases.diff().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20);
